# %%
import pandas as pd

# %% [markdown]
# ## 1. Triangular Fuzzy Model

# %%
trifm=pd.read_csv('trainset_results.csv',index_col=[0])
trifm
# Out:
#       LDEG   GDEG  Oracle    FHH
# 0    0.994  0.994   0.994  0.994
# 1    0.995  0.995   0.995  0.995
# 2    0.995  0.995   0.995  0.995
# 3    0.994  0.994   0.994  0.994
# 4    0.001  0.994   0.001  0.001
# ..     ...    ...     ...    ...
# 235  0.920  0.920   0.920  0.920
# 236  0.940  0.940   0.940  0.940
# 237  0.900  0.900   0.900  0.900
# 238  0.920  0.920   0.920  0.920
# 239  0.920  0.920   0.920  0.920
#
# [240 rows x 4 columns]

# %%
trifm.describe()
# Out:
#              LDEG        GDEG      Oracle         FHH
# count  240.000000  240.000000  240.000000  240.000000
# mean     0.925708    0.954583    0.925342    0.925708
# std      0.162014    0.039753    0.162052    0.162014
# min      0.001000    0.740000    0.001000    0.001000
# 25%      0.940000    0.940000    0.940000    0.940000
# 50%      0.961000    0.963000    0.960000    0.961000
# 75%      0.984000    0.985000    0.983250    0.984000
# max      0.996000    0.996000    0.996000    0.996000

# %%
boxplot1 = trifm.boxplot(column=['LDEG', 'GDEG', 'FHH'])

# %% [markdown]
# ## 2. Trapezoidal Fuzzy Model

# %%
trafm=pd.read_csv('trainset_results_trapezoidal.csv',index_col=[0])
trafm
# Out:
#       LDEG   GDEG  Fuzzy_Hyper_Heuristic
# 0    0.994  0.994                  0.994
# 1    0.995  0.995                  0.995
# 2    0.995  0.995                  0.995
# 3    0.994  0.994                  0.994
# 4    0.001  0.994                  0.001
# ..     ...    ...                    ...
# 115  0.940  0.940                  0.940
# 116  0.940  0.940                  0.940
# 117  0.940  0.940                  0.940
# 118  0.940  0.940                  0.940
# 119  0.940  0.940                  0.940
#
# [120 rows x 3 columns]

# %%
trafm.describe()
# Out:
#              LDEG        GDEG  Fuzzy_Hyper_Heuristic
# count  120.000000  120.000000             120.000000
# mean     0.957292    0.967175               0.957292
# std      0.094032    0.030607               0.094032
# min      0.001000    0.880000               0.001000
# 25%      0.940000    0.940000               0.940000
# 50%      0.970000    0.979000               0.970000
# 75%      0.992000    0.992500               0.992000
# max      0.996000    0.996000               0.996000

# %%
boxplot2 = trafm.boxplot(column=['LDEG', 'GDEG', 'Fuzzy_Hyper_Heuristic'])

# %% [markdown]
# ## 3. Gaussian Fuzzy Model

# %%
gaufm=pd.read_csv('trainset_results_gaussian.csv',index_col=[0])
gaufm
# Out:
#       LDEG   GDEG  Fuzzy_Hyper_Heuristic
# 0    0.994  0.994                  0.994
# 1    0.995  0.995                  0.995
# 2    0.995  0.995                  0.995
# 3    0.994  0.994                  0.994
# 4    0.001  0.994                  0.001
# ..     ...    ...                    ...
# 115  0.940  0.940                  0.940
# 116  0.940  0.940                  0.940
# 117  0.940  0.940                  0.940
# 118  0.940  0.940                  0.940
# 119  0.940  0.940                  0.940
#
# [120 rows x 3 columns]

# %%
gaufm.describe()
# Out:
#              LDEG        GDEG  Fuzzy_Hyper_Heuristic
# count  120.000000  120.000000             120.000000
# mean     0.957292    0.967175               0.957292
# std      0.094032    0.030607               0.094032
# min      0.001000    0.880000               0.001000
# 25%      0.940000    0.940000               0.940000
# 50%      0.970000    0.979000               0.970000
# 75%      0.992000    0.992500               0.992000
# max      0.996000    0.996000               0.996000

# %%
boxplot3 = gaufm.boxplot(column=['LDEG', 'GDEG', 'Fuzzy_Hyper_Heuristic'])
